# %%
# librerias

import numpy as np
import pandas as pd
import geopandas as gpd

pd.set_option('display.max_columns', None)

# %%
listings=pd.read_csv('../data/clean_data/listings.csv')

display(listings.head())

listings.shape
# Out:
#       id  host_id  host_is_superhost neighbourhood_cleansed  \
# 0   6369    13660                  1         Hispanoamérica
# 1  21853    83531                  0               Cármenes
# 2  23001    82175                  0                Legazpi
# 3  24805   101471                  0            Universidad
# 4  24836   101653                  1               Justicia
#
#   neighbourhood_group_cleansed  latitude  longitude property_type  \
# 0                    Chamartín  40.45628   -3.67763     Apartment
# 1                       Latina  40.40341   -3.74084     Apartment
# 2                   Arganzuela  40.38695   -3.69304     Apartment
# 3                       Centro  40.42202   -3.70395     Apartment
# 4                       Centro  40.41995   -3.69764     Apartment
#
#          room_type  accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0     Private room             2          1         1     0  Real Bed
# 1     Private room             1          1         1     1  Real Bed
# 2  Entire home/apt             6          2         3     5  Real Bed
# 3  Entire home/apt             3          1         0     1  Real Bed
# 4  Entire home/apt             4          1         2     3  Real Bed
#
#                                            amenities  price  security_deposit  \
# 0  {Wifi,"Air conditioning",Kitchen,Elevator,Heat...     70                 0
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...     17                 0
# 2  {TV,Internet,Wifi,"Air conditioning","Wheelcha...     50               300
# 3  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...     80               200
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...    115               200
#
#    cleaning_fee  guests_included  extra_people  minimum_nights  \
# 0             5                2            15               1
# 1             0                1             8               4
# 2            30                1            10              15
# 3            30                2             0               5
# 4             0                4             0               3
#
#    maximum_nights  availability_30  availability_60  availability_90  \
# 0             365               22               52               82
# 1              40                0                0                0
# 2             730                2                2                2
# 3             730               27               57               87
# 4              10               24               54               77
#
#    availability_365  number_of_reviews  number_of_reviews_ltm  \
# 0                82                 73                     14
# 1               162                 33                      0
# 2               213                  0                      0
# 3               362                  9                      7
# 4               342                 67                     15
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               6
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            6
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms
# 0                                            0
# 1                                            0
# 2                                            0
# 3                                            0
# 4                                            0
# (21312, 32)

# %%
for c in listings.select_dtypes(include=['int64','float64']):
    listings[c]=pd.to_numeric(listings[c], downcast='unsigned')

listings.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21312 entries, 0 to 21311
# Data columns (total 32 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            21312 non-null  uint32
#  1   host_id                                       21312 non-null  uint32
#  2   host_is_superhost                             21312 non-null  uint8
#  3   neighbourhood_cleansed                        21312 non-null  object
#  4   neighbourhood_group_cleansed                  21312 non-null  object
#  5   latitude                                      21312 non-null  float64
#  6   longitude                                     21312 non-null  float64
#  7   property_type                                 21312 non-null  object
#  8   room_type                                     21312 non-null  object
#  9   accommodates                                  21312 non-null  uint8
#  10  bathrooms                                     21312 non-null  uint8
#  11  bedrooms                                      21312 non-null  uint8
#  12  beds                                          21312 non-null  uint8
#  13  bed_type                                      21312 non-null  object
#  14  amenities                                     21312 non-null  object
#  15  price                                         21312 non-null  uint16
#  16  security_deposit                              21312 non-null  uint16
#  17  cleaning_fee                                  21312 non-null  uint16
#  18  guests_included                               21312 non-null  uint8
#  19  extra_people                                  21312 non-null  uint16
#  20  minimum_nights                                21312 non-null  uint16
#  21  maximum_nights                                21312 non-null  uint32
#  22  availability_30                               21312 non-null  uint8
#  23  availability_60                               21312 non-null  uint8
#  24  availability_90                               21312 non-null  uint8
#  25  availability_365                              21312 non-null  uint16
#  26  number_of_reviews                             21312 non-null  uint16
#  27  number_of_reviews_ltm                         21312 non-null  uint16
#  28  calculated_host_listings_count                21312 non-null  uint8
#  29  calculated_host_listings_count_entire_homes   21312 non-null  uint8
#  30  calculated_host_listings_count_private_rooms  21312 non-null  uint8
#  31  calculated_host_listings_count_shared_rooms   21312 non-null  uint8
# dtypes: float64(2), object(6), uint16(8), uint32(3), uint8(13)
# memory usage: 15.7 MB
