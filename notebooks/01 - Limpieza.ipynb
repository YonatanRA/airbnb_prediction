# %% [markdown]
# # 01 - Limpieza

# %% [markdown]
# ## Descripción de los datos
#
# Archivo | Descripción
# --------|------------
# [listings.csv.gz](http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2020-01-10/data/listings.csv.gz) | Detalle de las publicaciones
# [calendar.csv.gz](http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2020-01-10/data/calendar.csv.gz) | Datos detallados del calendario para las publicaciones
# [reviews.csv.gz](http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2020-01-10/data/reviews.csv.gz) | Datos detallados de las reseñas
# [listings.csv](http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2020-01-10/visualisations/listings.csv) | Resumen de información y métricas para las publicaciones
# [reviews.csv](http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2020-01-10/visualisations/reviews.csv) | Resumen de reseñas
# [neighbourhoods.csv](http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2020-01-10/visualisations/neighbourhoods.csv) | Lista de barrios. Procedente de archivos GIS de código abierto o de la ciudad
# [neighbourhoods.geojson](http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2020-01-10/visualisations/neighbourhoods.geojson) | Archivo GeoJSON de barrios de la ciudad

# %% [markdown]
# [Link](https://docs.google.com/spreadsheets/d/1iWCNJcSutYqpULSQHlNyGInUvHg2BoUGoNRIGa6Szc4/edit#gid=150111846) con toda la descripción de cada dataset.

# %% [markdown]
# El dataset `listings.csv` está dentro de `listings.csv.gz` y también `reviews.csv` está dentro de `reviews.csv.gz`. Se cargan solamente los `.gz`.

# %% [markdown]
# El objetivo de este notebook es limpiar los datasets de registros duplicados, valores nulos, consistencia en el tipo de dato, etc...

# %%
# librerias

import numpy as np
import pandas as pd
import geopandas as gpd

pd.set_option('display.max_columns', None)

import pylab as plt
import seaborn as sns

# %%
listings=pd.read_csv('../data/raw_data/listings.csv.gz', compression='gzip', low_memory=False)

display(listings.head())

listings.shape
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0   6369   https://www.airbnb.com/rooms/6369  20200110222856   2020-01-11
# 1  21853  https://www.airbnb.com/rooms/21853  20200110222856   2020-01-11
# 2  23001  https://www.airbnb.com/rooms/23001  20200110222856   2020-01-11
# 3  24805  https://www.airbnb.com/rooms/24805  20200110222856   2020-01-11
# 4  24836  https://www.airbnb.com/rooms/24836  20200110222856   2020-01-11
#
#                                        name  \
# 0  Rooftop terrace room ,  ensuite bathroom
# 1                      Bright and airy room
# 2         Apartmento Arganzuela- Madrid Rio
# 3                    Gran Via Studio Madrid
# 4            Select the Madrid more "cool".
#
#                                              summary  \
# 0  Excellent connection with the AIRPORT and EXHI...
# 1  We have a quiet and sunny room with a good vie...
# 2  Apartamento de tres dormitorios dobles, gran s...
# 3  Studio located 50 meters from Gran Via, next t...
# 4  Apartamento céntrico junto a Gran Vía (VT-296)...
#
#                                                space  \
# 0  BETTER THAN A HOTEL.Upscale neighboorhood (Met...
# 1  I am living in a nice flat near the centre of ...
# 2  Apartamento de lujo, tres dormitorios dobles i...
# 3  LOCATION.  Brand new flats near the Atlantic H...
# 4  Select the Madrid more "cool" : 70 m, 2 bedroo...
#
#                                          description experiences_offered  \
# 0  Excellent connection with the AIRPORT and EXHI...                none
# 1  We have a quiet and sunny room with a good vie...                none
# 2  Apartamento de tres dormitorios dobles, gran s...                none
# 3  Studio located 50 meters from Gran Via, next t...                none
# 4  Select the Madrid more "cool" : 70 m, 2 bedroo...                none
#
#                                neighborhood_overview  \
# 0  Nice and definitely  non touristic neighborhoo...
# 1  We live in a leafy neighbourhood with plenty o...
# 2  Barrio Arganzuela, junto a Madrid Rio, zonas c...
# 3  The area is next to the Gran Via, so people li...
# 4  Cosmopolita, lleno de locales de moda, restaur...
#
#                                                notes  \
# 0  If you are a group/family 3 or 4 people we off...
# 1  We are a 15 min bus ride away from the Casa de...
# 2                                                NaN
# 3                              Just enjoy your trip.
# 4  Al estar en el distrito Centro (Barrio de Just...
#
#                                              transit  \
# 0  Excelent public transport and easy Access to m...
# 1  The flat is near the centre of Madrid (15 minu...
# 2                                                NaN
# 3  To go from the airport you have several differ...
# 4  La situación del apartamento hace accesibles a...
#
#                                               access  \
# 0  Full use of living room, kitchen (with dishwas...
# 1  There is fibre optic internet connection for y...
# 2  Piscina de verano, zonas comunes en el interio...
# 3  Apartment with elevator has a storage room for...
# 4  La disponibilidad de acceso al apartamento es ...
#
#                                          interaction  \
# 0  English, spanish, german, russian, some french...
# 1  If I am at home and see each other around here...
# 2                                                NaN
# 3  I put at the disposal of my guests to facilita...
# 4  El precio marcado es por el alojamiento comple...
#
#                                          house_rules  thumbnail_url  \
# 0                                                NaN            NaN
# 1  Gracias por no fumar en la casa. Es muy import...            NaN
# 2  Preparacion apartamento , entrega llaves 20 € ...            NaN
# 3  Durante tu estancia es tu casa. Sientete en el...            NaN
# 4  El apartamento admite bebés, aunque no tiene c...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/683224/4cc...
# 1         NaN  https://a0.muscache.com/im/pictures/68483181/8...
# 2         NaN  https://a0.muscache.com/im/pictures/58e6a770-5...
# 3         NaN  https://a0.muscache.com/im/pictures/5843578f-6...
# 4         NaN  https://a0.muscache.com/im/pictures/573273/8f5...
#
#    xl_picture_url  host_id                                  host_url  \
# 0             NaN    13660   https://www.airbnb.com/users/show/13660
# 1             NaN    83531   https://www.airbnb.com/users/show/83531
# 2             NaN    82175   https://www.airbnb.com/users/show/82175
# 3             NaN   101471  https://www.airbnb.com/users/show/101471
# 4             NaN   101653  https://www.airbnb.com/users/show/101653
#
#   host_name  host_since                       host_location  \
# 0     Simon  2009-04-16               Madrid, Madrid, Spain
# 1     Abdel  2010-02-21               Madrid, Madrid, Spain
# 2     Jesus  2010-02-17  Madrid, Community of Madrid, Spain
# 3    Iraido  2010-03-31               Madrid, Madrid, Spain
# 4     Tenty  2010-03-31            Las Rozas, Madrid, Spain
#
#                                           host_about  host_response_time  \
# 0  Gay couple, heterofriendly, enjoy having guest...      within an hour
# 1  EN-ES-FR\r\nEN\r\nHi everybody: I'm Abdel. I'm...                 NaN
# 2  Hi,\r\n\r\nWelcome to my apartments in the dow...      within an hour
# 3  I love treating my clients, how I would like t...  within a few hours
# 4  Mi mayor pasión es viajar y conocer culturas d...      within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 t
# 1                NaN                   NaN                 f
# 2               100%                   NaN                 f
# 3               100%                   NaN                 f
# 4               100%                   NaN                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/pictures/user/1c793...
# 1  https://a0.muscache.com/im/users/83531/profile...
# 2  https://a0.muscache.com/im/pictures/user/52bdf...
# 3  https://a0.muscache.com/im/pictures/user/233f4...
# 4  https://a0.muscache.com/im/users/101653/profil...
#
#                                     host_picture_url  \
# 0  https://a0.muscache.com/im/pictures/user/1c793...
# 1  https://a0.muscache.com/im/users/83531/profile...
# 2  https://a0.muscache.com/im/pictures/user/52bdf...
# 3  https://a0.muscache.com/im/pictures/user/233f4...
# 4  https://a0.muscache.com/im/users/101653/profil...
#
#               host_neighbourhood  host_listings_count  \
# 0                 Hispanoamérica                  1.0
# 1                         Aluche                  2.0
# 2  Erzsébetváros - District VII.                 10.0
# 3                       Malasaña                  1.0
# 4                       Justicia                  1.0
#
#    host_total_listings_count  \
# 0                        1.0
# 1                        2.0
# 2                       10.0
# 3                        1.0
# 4                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 1  ['email', 'phone', 'reviews', 'manual_offline'...                    t
# 2  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
# 3  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
# 4          ['email', 'phone', 'facebook', 'reviews']                    t
#
#   host_identity_verified                              street neighbourhood  \
# 0                      f  Madrid, Comunidad de Madrid, Spain     Chamartín
# 1                      t               Madrid, Madrid, Spain        Aluche
# 2                      f  Madrid, Comunidad de Madrid, Spain       Legazpi
# 3                      t               Madrid, Madrid, Spain      Malasaña
# 4                      f  Madrid, Comunidad de Madrid, Spain      Justicia
#
#   neighbourhood_cleansed neighbourhood_group_cleansed    city  \
# 0         Hispanoamérica                    Chamartín  Madrid
# 1               Cármenes                       Latina  Madrid
# 2                Legazpi                   Arganzuela  Madrid
# 3            Universidad                       Centro  Madrid
# 4               Justicia                       Centro  Madrid
#
#                  state zipcode  market smart_location country_code country  \
# 0  Comunidad de Madrid   28016  Madrid  Madrid, Spain           ES   Spain
# 1               Madrid   28047  Madrid  Madrid, Spain           ES   Spain
# 2  Comunidad de Madrid   28045  Madrid  Madrid, Spain           ES   Spain
# 3               Madrid   28004  Madrid  Madrid, Spain           ES   Spain
# 4  Comunidad de Madrid   28004  Madrid  Madrid, Spain           ES   Spain
#
#    latitude  longitude is_location_exact property_type        room_type  \
# 0  40.45628   -3.67763                 t     Apartment     Private room
# 1  40.40341   -3.74084                 f     Apartment     Private room
# 2  40.38695   -3.69304                 t     Apartment  Entire home/apt
# 3  40.42202   -3.70395                 t     Apartment  Entire home/apt
# 4  40.41995   -3.69764                 f     Apartment  Entire home/apt
#
#    accommodates  bathrooms  bedrooms  beds  bed_type  \
# 0             2        1.0       1.0   0.0  Real Bed
# 1             1        1.0       1.0   1.0  Real Bed
# 2             6        2.0       3.0   5.0  Real Bed
# 3             3        1.0       0.0   1.0  Real Bed
# 4             4        1.5       2.0   3.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {Wifi,"Air conditioning",Kitchen,Elevator,Heat...        172.0   $70.00
# 1  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...         97.0   $17.00
# 2  {TV,Internet,Wifi,"Air conditioning","Wheelcha...       1184.0   $50.00
# 3  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...          0.0   $80.00
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $115.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $350.00       $950.00            $0.00        $5.00                2
# 1       $98.00       $370.00              NaN          NaN                1
# 2      $556.00     $1,500.00          $300.00       $30.00                1
# 3      $450.00     $1,200.00          $200.00       $30.00                2
# 4      $600.00           NaN          $200.00        $0.00                4
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $15.00               1             365                       1
# 1        $8.00               4              40                       4
# 2       $10.00              15             730                       7
# 3        $0.00               5             730                       5
# 4        $0.00               3              10                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       1                     365                     365
# 1                       4                      40                      40
# 2                      15                     730                     730
# 3                       5                     730                     730
# 4                       3                      10                      10
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     1.0                   365.0       5 days ago
# 1                     4.0                    40.0    12 months ago
# 2                    14.5                   730.0      2 weeks ago
# 3                     5.0                   730.0     2 months ago
# 4                     3.0                    10.0       2 days ago
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               22               52               82
# 1                t                0                0                0
# 2                t                2                2                2
# 3                t               27               57               87
# 4                t               24               54               77
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                82            2020-01-11                 73
# 1               162            2020-01-11                 33
# 2               213            2020-01-11                  0
# 3               362            2020-01-11                  9
# 4               342            2020-01-11                 67
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                     14   2010-03-14  2019-12-13                  98.0
# 1                      0   2014-10-10  2018-07-15                  92.0
# 2                      0          NaN         NaN                   NaN
# 3                      7   2014-11-29  2020-01-03                  98.0
# 4                     15   2011-06-02  2019-12-08                  98.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                     9.0                        9.0                   10.0
# 2                     NaN                        NaN                    NaN
# 3                     9.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                     8.0                  9.0
# 2                          NaN                     NaN                  NaN
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license license  jurisdiction_names instant_bookable  \
# 0                t     NaN                 NaN                f
# 1                t     NaN                 NaN                f
# 2                t     NaN                 NaN                f
# 3                t     NaN                 NaN                f
# 4                t  VT-296                 NaN                f
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f                     flexible
# 1                        f  strict_14_with_grace_period
# 2                        f                     moderate
# 3                        f                     moderate
# 4                        f                     moderate
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                f
# 3                             f                                f
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               6
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            6
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.61
# 1                                            0               0.52
# 2                                            0                NaN
# 3                                            0               0.14
# 4                                            0               0.64
# (21495, 106)

# %%
calendar=pd.read_csv('../data/raw_data/calendar.csv.gz', compression='gzip', low_memory=False)

display(calendar.head())

calendar.shape
# Out:
#    listing_id        date available   price adjusted_price  minimum_nights  \
# 0        6369  2020-01-11         f  $80.00         $80.00             1.0
# 1       96072  2020-01-11         f  $25.00         $25.00             3.0
# 2       96072  2020-01-12         f  $25.00         $25.00             3.0
# 3       96072  2020-01-13         f  $25.00         $25.00             3.0
# 4       96072  2020-01-14         f  $25.00         $25.00             3.0
#
#    maximum_nights
# 0           365.0
# 1           365.0
# 2           365.0
# 3           365.0
# 4           365.0
# (7845708, 7)

# %%
reviews=pd.read_csv('../data/raw_data/reviews.csv.gz', compression='gzip', low_memory=False)

display(reviews.head())

reviews.shape
# Out:
#    listing_id     id        date  reviewer_id reviewer_name  \
# 0        6369  29428  2010-03-14        84790         Nancy
# 1        6369  31018  2010-03-23        84338         David
# 2        6369  34694  2010-04-10        98655        Marion
# 3        6369  37146  2010-04-21       109871          Kurt
# 4        6369  38168  2010-04-26        98901        Dennis
#
#                                             comments
# 0  Simon and Arturo have the ultimate location in...
# 1  Myself and Kristy originally planned on stayin...
# 2  We had a great time at Arturo and Simon's ! A ...
# 3  I very much enjoyed the stay.  \r\nIt's a wond...
# 4  Arturo and Simon are polite and friendly hosts...
# (812726, 6)

# %%
geo_neighbourhoods=gpd.read_file('../data/raw_data/neighbourhoods.geojson')

display(geo_neighbourhoods.head())

geo_neighbourhoods.shape
# Out:
#   neighbourhood neighbourhood_group  \
# 0       Palacio              Centro
# 1   Embajadores              Centro
# 2        Cortes              Centro
# 3      Justicia              Centro
# 4   Universidad              Centro
#
#                                             geometry
# 0  MULTIPOLYGON (((-3.70584 40.42030, -3.70625 40...
# 1  MULTIPOLYGON (((-3.70384 40.41432, -3.70277 40...
# 2  MULTIPOLYGON (((-3.69796 40.41929, -3.69645 40...
# 3  MULTIPOLYGON (((-3.69546 40.41898, -3.69645 40...
# 4  MULTIPOLYGON (((-3.70107 40.42134, -3.70155 40...
# (128, 3)

# %% [markdown]
# ## a) Limpieza listings

# %% [markdown]
# Primero, elimino columnas con valores constantes o columnas no informativas. Eliminaré también columnas relacionadas con el host, como `name` o `summary` para evitar sesgos (quizá habría que analizarlas aparte). Veámoslas de una en una.
#
# + listing_url: Url del piso, con el id nos vale.
# + scrape_id: Id de la extracción de los datos, en realidad es la fecha de extracción.
# + last_scraped: fecha de la última extracción de datos.
# + name: nombre que el host pone al piso.
# + summary: resumen que hace el host sobre el piso.
# + space: descripción que hace el host sobre el piso.
# + description: descripción que hace el host sobre el barrio (detallado).
# + experiences_offered: columna constante, todo nulos.
# + neighborhood_overview: descripción que hace el host sobre el barrio.
# + notes: notas que hace el host.
# + transit: notas que hace el host.
# + access: notas de acceso.
# + interaction: descripción del host de idiomas etc..
# + house_rules: normas de la casa.
# + thumbnail_url: toda la columna nula.
# + medium_url: toda la columna nula.
# + picture_url: Url de la imagen, irrelevante.
# + xl_picture_url: Url de la imagen, irrelevante. toda la columna nula.
# + host_url: Url del host, nos vale el id
# + host_name: nombre del host, irrelevante.
# + host_since: fecha desde ser host, borrada por sesgo.
# + host_location: localidad del host, irrelevante.
# + host_about: descripción sobre el host.
# + host_response_time: respuesta en tiempo del host.
# + host_response_rate: tasa de respuesta del host.
# + host_acceptance_rate: toda la columna nula.
# + host_thumbnail_url: información irrelevante sobre el host.
# + host_picture_url: información irrelevante sobre el host.
# + host_neighbourhood: información irrelevante sobre el host.
# + host_listings_count: información irrelevante sobre el host.
# + host_total_listings_count: información irrelevante sobre el host.
# + host_verifications: formas de verificación/contacto del host.
# + host_has_profile_pic: foto del host (si la tiene o no).
# + host_identity_verified: host verificado o no.
# + street: básicamente es Madrid.
# + neighbourhood: barrio. La elimino porque está neighbourhood_cleansed, construida por geolocalización.
# + city: básicamente es Madrid.
# + state: básicamente es Madrid.
# + zipcode: irrelevante, tenemos latitud y longitud, además de los nombre de los barrios.
# + market: básicamente es Madrid.
# + country_code: básicamente es España.
# + country: básicamente es España.
# + is_location_exact: localización exacta, tenemos latitud y longitud.
# + minimum_minimum_nights: elimino estas columnas porque ya tenemos mínimo nº de noches
# + maximum_minimum_nights: elimino estas columnas porque ya tenemos mínimo nº de noches
# + minimum_maximum_nights: elimino estas columnas porque ya tenemos mínimo nº de noches
# + maximum_maximum_nights: elimino estas columnas porque ya tenemos máximo nº de noches
# + minimum_nights_avg_ntm: elimino estas columnas porque ya tenemos máximo nº de noches
# + maximum_nights_avg_ntm: elimino estas columnas porque ya tenemos máximo nº de noches
# + calendar_updated: última actualización del calendario.
# + has_availability: columna constante.
# + calendar_last_scraped: última extracción del dato de calendario.
# + first_review: fecha primera review, las reviews se analizarán por separado.
# + last_review: fecha últime review,las reviews se analizarán por separado.
# + requires_license: columna constante.
# + license: nº de licencia.
# + jurisdiction_names: columna entera de nulos.
# + instant_bookable: reserva instantánea, irrelevante desde el punto de vista del precio, quizá no desde la demanda.
# + is_business_travel_ready: columna constante.
# + cancellation_policy: política de cancelación, irrelevante desde el punto de vista del precio, quizá no desde la demanda.
# + require_guest_profile_picture: requerida imagen del visitante.
# + require_guest_phone_verification: verificación por teléfono.
#
# **Todas estas columnas serán eliminadas del dataset.**

# %%
cols_to_drop=['listing_url', 'scrape_id', 'last_scraped', 'name', 'summary', 'space', 'description',
              'experiences_offered', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction',
              'house_rules', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 
              'host_name', 'host_since', 'host_location', 'host_about', 'host_response_time', 'host_response_rate', 
              'host_acceptance_rate', 'host_thumbnail_url', 'host_picture_url', 'host_neighbourhood', 
              'host_listings_count', 'host_total_listings_count', 'host_verifications', 'host_has_profile_pic',
              'host_identity_verified', 'street', 'neighbourhood', 'city', 'state', 'zipcode', 'market',
              'country_code', 'country', 'is_location_exact', 'minimum_minimum_nights', 'maximum_minimum_nights',
              'minimum_maximum_nights', 'maximum_maximum_nights', 'minimum_nights_avg_ntm', 'maximum_nights_avg_ntm',
              'calendar_updated', 'has_availability', 'calendar_last_scraped', 'first_review', 'last_review',
              'requires_license', 'license', 'jurisdiction_names', 'instant_bookable', 'is_business_travel_ready',
              'cancellation_policy', 'require_guest_profile_picture', 'require_guest_phone_verification', 
              ]

len(cols_to_drop)
# Out:
# 62

# %%
listings.drop(columns=cols_to_drop, inplace=True)

listings.head()
# Out:
#       id  host_id host_is_superhost neighbourhood_cleansed  \
# 0   6369    13660                 t         Hispanoamérica
# 1  21853    83531                 f               Cármenes
# 2  23001    82175                 f                Legazpi
# 3  24805   101471                 f            Universidad
# 4  24836   101653                 t               Justicia
#
#   neighbourhood_group_cleansed smart_location  latitude  longitude  \
# 0                    Chamartín  Madrid, Spain  40.45628   -3.67763
# 1                       Latina  Madrid, Spain  40.40341   -3.74084
# 2                   Arganzuela  Madrid, Spain  40.38695   -3.69304
# 3                       Centro  Madrid, Spain  40.42202   -3.70395
# 4                       Centro  Madrid, Spain  40.41995   -3.69764
#
#   property_type        room_type  accommodates  bathrooms  bedrooms  beds  \
# 0     Apartment     Private room             2        1.0       1.0   0.0
# 1     Apartment     Private room             1        1.0       1.0   1.0
# 2     Apartment  Entire home/apt             6        2.0       3.0   5.0
# 3     Apartment  Entire home/apt             3        1.0       0.0   1.0
# 4     Apartment  Entire home/apt             4        1.5       2.0   3.0
#
#    bed_type                                          amenities  square_feet  \
# 0  Real Bed  {Wifi,"Air conditioning",Kitchen,Elevator,Heat...        172.0
# 1  Real Bed  {TV,Internet,Wifi,"Air conditioning",Kitchen,"...         97.0
# 2  Real Bed  {TV,Internet,Wifi,"Air conditioning","Wheelcha...       1184.0
# 3  Real Bed  {TV,Internet,Wifi,"Air conditioning",Kitchen,E...          0.0
# 4  Real Bed  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN
#
#      price weekly_price monthly_price security_deposit cleaning_fee  \
# 0   $70.00      $350.00       $950.00            $0.00        $5.00
# 1   $17.00       $98.00       $370.00              NaN          NaN
# 2   $50.00      $556.00     $1,500.00          $300.00       $30.00
# 3   $80.00      $450.00     $1,200.00          $200.00       $30.00
# 4  $115.00      $600.00           NaN          $200.00        $0.00
#
#    guests_included extra_people  minimum_nights  maximum_nights  \
# 0                2       $15.00               1             365
# 1                1        $8.00               4              40
# 2                1       $10.00              15             730
# 3                2        $0.00               5             730
# 4                4        $0.00               3              10
#
#    availability_30  availability_60  availability_90  availability_365  \
# 0               22               52               82                82
# 1                0                0                0               162
# 2                2                2                2               213
# 3               27               57               87               362
# 4               24               54               77               342
#
#    number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# 0                 73                     14                  98.0
# 1                 33                      0                  92.0
# 2                  0                      0                   NaN
# 3                  9                      7                  98.0
# 4                 67                     15                  98.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                     9.0                        9.0                   10.0
# 2                     NaN                        NaN                    NaN
# 3                     9.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                     8.0                  9.0
# 2                          NaN                     NaN                  NaN
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#    calculated_host_listings_count  \
# 0                               1
# 1                               2
# 2                               6
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            0
# 1                                            0
# 2                                            6
# 3                                            1
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             2
# 2                                             0
# 3                                             0
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.61
# 1                                            0               0.52
# 2                                            0                NaN
# 3                                            0               0.14
# 4                                            0               0.64

# %%
listings.shape
# Out:
# (21495, 44)

# %% [markdown]
# Ahora se exploran valores duplicados y valores nulos.

# %%
listings.duplicated().any() # en principio no existen valores duplicados
# Out:
# False

# %%
def check_nan(df: pd.DataFrame) -> None:
    """
    Esta función comprueba los nulos de un dataframe.
    Calcula el porcentaje de nulos por columnas, las enseña 
    y además realiza un gráfico para verlos mejor.
    
    param df: pandas DataFrame a ser checkeado.
    
    return: None (sólo printea y grafica)
    
    """
    
    nan=df.isna().mean() * 100
    
    nan_cols=nan[nan>0]
    
    display(f'N nan cols: {len(nan_cols)}')
    display(nan_cols)
    
    plt.figure(figsize=(10, 6))

    sns.heatmap(df.isna(), 
                xticklabels=False,
                yticklabels=False,
                cmap='viridis',
                cbar=False)

    plt.show();

# %%
check_nan(listings)
# Out:
# 'N nan cols: 17'
# host_is_superhost               0.116306
# bathrooms                       0.069784
# bedrooms                        0.074436
# beds                            0.646662
# square_feet                    98.599674
# weekly_price                   92.370319
# monthly_price                  92.849500
# security_deposit               32.821586
# cleaning_fee                   24.307979
# review_scores_rating           21.200279
# review_scores_accuracy         21.204931
# review_scores_cleanliness      21.195627
# review_scores_checkin          21.190975
# review_scores_communication    21.190975
# review_scores_location         21.204931
# review_scores_value            21.209584
# reviews_per_month              19.962782
# dtype: float64
